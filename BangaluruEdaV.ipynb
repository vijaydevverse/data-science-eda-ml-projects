# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaydevverse/data-science-eda-ml-projects/blob/main/BangaluruEdaV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Bengaluru_House_Data (2).csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.drop("society",axis=1,inplace=True)

# %%
df.dropna(subset=["size"],inplace=True)

# %%
df.dropna(subset=["bath"],inplace=True)

# %%
df.dropna(subset=["location"],inplace=True)

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# total_sqft        0
# bath              0
# balcony         536
# price             0
# dtype: int64

# %%
df.drop("balcony",axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# price           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(668)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13246 entries, 0 to 13319
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13246 non-null  object
#  1   availability  13246 non-null  object
#  2   location      13246 non-null  object
#  3   size          13246 non-null  object
#  4   total_sqft    13246 non-null  object
#  5   bath          13246 non-null  float64
#  6   price         13246 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 827.9+ KB

# %%
df.shape
# Out:
# (13246, 7)

# %%
df["area_type"].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df["area_type"].replace(['Super built-up  Area', 'Plot  Area', 'Built-up  Area', 'Carpet  Area'],[1,2,3,4],inplace=True)
# Out:
# /tmp/ipython-input-2299942626.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["area_type"].replace(['Super built-up  Area', 'Plot  Area', 'Built-up  Area', 'Carpet  Area'],[1,2,3,4],inplace=True)
# /tmp/ipython-input-2299942626.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["area_type"].replace(['Super built-up  Area', 'Plot  Area', 'Built-up  Area', 'Carpet  Area'],[1,2,3,4],inplace=True)

# %%
df["availability"].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '18-Apr',
#        '20-Aug', '19-Mar', '17-Sep', '18-Dec', '17-Aug', '19-Apr',
#        '18-Jun', '22-Dec', '22-Jan', '18-Aug', '19-Jan', '17-Jul',
#        '18-Jul', '21-Jun', '20-May', '19-Aug', '18-Sep', '17-May',
#        '17-Jun', '18-Oct', '21-May', '18-Jan', '20-Mar', '17-Dec',
#        '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb', '19-May',
#        '17-Nov', '20-Oct', '20-Jun', '19-Feb', '21-Oct', '21-Jan',
#        '17-Mar', '17-Apr', '22-May', '19-Oct', '21-Jul', '21-Nov',
#        '21-Mar', '16-Dec', '22-Mar', '20-Jan', '21-Sep', '21-Aug',
#        '14-Nov', '19-Nov', '15-Nov', '16-Jul', '15-Jun', '17-Feb',
#        '20-Nov', '20-Jul', '16-Sep', '15-Oct', '20-Feb', '15-Dec',
#        '16-Oct', '22-Nov', '15-Aug', '17-Jan', '16-Nov', '20-Apr',
#        '16-Jan', '14-Jul'], dtype=object)

# %%
df['availability'] = pd.to_datetime(df['availability'], format='%d-%b', errors='coerce')

# %%
median_date = df['availability'].median()

# %%
# Replace NaT with this middle date
df['availability'] = df['availability'].fillna(median_date)

# %%
df
# Out:
#        area_type availability                  location       size total_sqft  \
# 0              1   1900-12-19  Electronic City Phase II      2 BHK       1056
# 1              2   1900-07-18          Chikka Tirupathi  4 Bedroom       2600
# 2              3   1900-07-18               Uttarahalli      3 BHK       1440
# 3              1   1900-07-18        Lingadheeranahalli      3 BHK       1521
# 4              1   1900-07-18                  Kothanur      2 BHK       1200
# ...          ...          ...                       ...        ...        ...
# 13315          3   1900-07-18                Whitefield  5 Bedroom       3453
# 13316          1   1900-07-18             Richards Town      4 BHK       3600
# 13317          3   1900-07-18     Raja Rajeshwari Nagar      2 BHK       1141
# 13318          1   1900-06-18           Padmanabhanagar      4 BHK       4689
# 13319          1   1900-07-18              Doddathoguru      1 BHK        550
#
#        bath   price
# 0       2.0   39.07
# 1       5.0  120.00
# 2       2.0   62.00
# 3       3.0   95.00
# 4       2.0   51.00
# ...     ...     ...
# 13315   4.0  231.00
# 13316   5.0  400.00
# 13317   2.0   60.00
# 13318   4.0  488.00
# 13319   1.0   17.00
#
# [13246 rows x 7 columns]

# %%
df["availability"].unique()
# Out:
# <DatetimeArray>
# ['1900-12-19 00:00:00', '1900-07-18 00:00:00', '1900-05-18 00:00:00',
#  '1900-02-18 00:00:00', '1900-11-18 00:00:00', '1900-12-20 00:00:00',
#  '1900-10-17 00:00:00', '1900-12-21 00:00:00', '1900-09-19 00:00:00',
#  '1900-09-20 00:00:00', '1900-03-18 00:00:00', '1900-04-18 00:00:00',
#  '1900-08-20 00:00:00', '1900-03-19 00:00:00', '1900-09-17 00:00:00',
#  '1900-12-18 00:00:00', '1900-08-17 00:00:00', '1900-04-19 00:00:00',
#  '1900-06-18 00:00:00', '1900-12-22 00:00:00', '1900-01-22 00:00:00',
#  '1900-08-18 00:00:00', '1900-01-19 00:00:00', '1900-07-17 00:00:00',
#  '1900-06-21 00:00:00', '1900-05-20 00:00:00', '1900-08-19 00:00:00',
#  '1900-09-18 00:00:00', '1900-05-17 00:00:00', '1900-06-17 00:00:00',
#  '1900-10-18 00:00:00', '1900-05-21 00:00:00', '1900-01-18 00:00:00',
#  '1900-03-20 00:00:00', '1900-12-17 00:00:00', '1900-03-16 00:00:00',
#  '1900-06-19 00:00:00', '1900-06-22 00:00:00', '1900-07-19 00:00:00',
#  '1900-02-21 00:00:00', '1900-05-19 00:00:00', '1900-11-17 00:00:00',
#  '1900-10-20 00:00:00', '1900-06-20 00:00:00', '1900-02-19 00:00:00',
#  '1900-10-21 00:00:00', '1900-01-21 00:00:00', '1900-03-17 00:00:00',
#  '1900-04-17 00:00:00', '1900-05-22 00:00:00', '1900-10-19 00:00:00',
#  '1900-07-21 00:00:00', '1900-11-21 00:00:00', '1900-03-21 00:00:00',
#  '1900-12-16 00:00:00', '1900-03-22 00:00:00', '1900-01-20 00:00:00',
#  '1900-09-21 00:00:00', '1900-08-21 00:00:00', '1900-11-14 00:00:00',
#  '1900-11-19 00:00:00', '1900-11-15 00:00:00', '1900-07-16 00:00:00',
#  '1900-06-15 00:00:00', '1900-02-17 00:00:00', '1900-11-20 00:00:00',
#  '1900-07-20 00:00:00', '1900-09-16 00:00:00', '1900-10-15 00:00:00',
#  '1900-02-20 00:00:00', '1900-12-15 00:00:00', '1900-10-16 00:00:00',
#  '1900-11-22 00:00:00', '1900-08-15 00:00:00', '1900-01-17 00:00:00',
#  '1900-11-16 00:00:00', '1900-04-20 00:00:00', '1900-01-16 00:00:00',
#  '1900-07-14 00:00:00']
# Length: 79, dtype: datetime64[ns]

# %%
df["size"].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df["month"]=df["availability"].dt.month
df["year"]=df["availability"].dt.year
df["date"]=df["availability"].dt.date

# %%
df.drop("availability",axis=1,inplace=True)

# %%
df.drop("year",axis=1,inplace=True)

# %%
df
# Out:
#        area_type                  location       size total_sqft  bath  \
# 0              1  Electronic City Phase II      2 BHK       1056   2.0
# 1              2          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2              3               Uttarahalli      3 BHK       1440   2.0
# 3              1        Lingadheeranahalli      3 BHK       1521   3.0
# 4              1                  Kothanur      2 BHK       1200   2.0
# ...          ...                       ...        ...        ...   ...
# 13315          3                Whitefield  5 Bedroom       3453   4.0
# 13316          1             Richards Town      4 BHK       3600   5.0
# 13317          3     Raja Rajeshwari Nagar      2 BHK       1141   2.0
# 13318          1           Padmanabhanagar      4 BHK       4689   4.0
# 13319          1              Doddathoguru      1 BHK        550   1.0
#
#         price  month        date
# 0       39.07     12  1900-12-19
# 1      120.00      7  1900-07-18
# 2       62.00      7  1900-07-18
# 3       95.00      7  1900-07-18
# 4       51.00      7  1900-07-18
# ...       ...    ...         ...
# 13315  231.00      7  1900-07-18
# 13316  400.00      7  1900-07-18
# 13317   60.00      7  1900-07-18
# 13318  488.00      6  1900-06-18
# 13319   17.00      7  1900-07-18
#
# [13246 rows x 8 columns]

# %%
df["size"].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
a="2 BHK"
print(a.split())
# Out:
# ['2', 'BHK']

# %%
def split_features(value):
    if 'BHK' in value:

        bedroom=int(value.split()[0])
        hall=1
        kitchen=1
    elif 'Bedroom' in value:

        bedroom=int(value.split()[0])
        hall=0
        kitchen=0
    elif value=='1 RK':
        bedroom=1
        hall=0
        kitchen=1
    else:
        bedroom=None
        hall=None
        kitchen=None
    return bedroom,hall,kitchen

df[['Bedroom','Hall','Kitchen']]=df['size'].apply(lambda x: pd.Series(split_features(x)))

df
# Out:
#        area_type                  location       size total_sqft  bath  \
# 0              1  Electronic City Phase II      2 BHK       1056   2.0
# 1              2          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2              3               Uttarahalli      3 BHK       1440   2.0
# 3              1        Lingadheeranahalli      3 BHK       1521   3.0
# 4              1                  Kothanur      2 BHK       1200   2.0
# ...          ...                       ...        ...        ...   ...
# 13315          3                Whitefield  5 Bedroom       3453   4.0
# 13316          1             Richards Town      4 BHK       3600   5.0
# 13317          3     Raja Rajeshwari Nagar      2 BHK       1141   2.0
# 13318          1           Padmanabhanagar      4 BHK       4689   4.0
# 13319          1              Doddathoguru      1 BHK        550   1.0
#
#         price  month        date  Bedroom  Hall  Kitchen
# 0       39.07     12  1900-12-19        2     1        1
# 1      120.00      7  1900-07-18        4     0        0
# 2       62.00      7  1900-07-18        3     1        1
# 3       95.00      7  1900-07-18        3     1        1
# 4       51.00      7  1900-07-18        2     1        1
# ...       ...    ...         ...      ...   ...      ...
# 13315  231.00      7  1900-07-18        5     0        0
# 13316  400.00      7  1900-07-18        4     1        1
# 13317   60.00      7  1900-07-18        2     1        1
# 13318  488.00      6  1900-06-18        4     1        1
# 13319   17.00      7  1900-07-18        1     1        1
#
# [13246 rows x 11 columns]

# %%
df.drop("size",axis=1,inplace=True)

# %%
df
# Out:
#        area_type                  location total_sqft  bath   price  month  \
# 0              1  Electronic City Phase II       1056   2.0   39.07     12
# 1              2          Chikka Tirupathi       2600   5.0  120.00      7
# 2              3               Uttarahalli       1440   2.0   62.00      7
# 3              1        Lingadheeranahalli       1521   3.0   95.00      7
# 4              1                  Kothanur       1200   2.0   51.00      7
# ...          ...                       ...        ...   ...     ...    ...
# 13315          3                Whitefield       3453   4.0  231.00      7
# 13316          1             Richards Town       3600   5.0  400.00      7
# 13317          3     Raja Rajeshwari Nagar       1141   2.0   60.00      7
# 13318          1           Padmanabhanagar       4689   4.0  488.00      6
# 13319          1              Doddathoguru        550   1.0   17.00      7
#
#              date  Bedroom  Hall  Kitchen
# 0      1900-12-19        2     1        1
# 1      1900-07-18        4     0        0
# 2      1900-07-18        3     1        1
# 3      1900-07-18        3     1        1
# 4      1900-07-18        2     1        1
# ...           ...      ...   ...      ...
# 13315  1900-07-18        5     0        0
# 13316  1900-07-18        4     1        1
# 13317  1900-07-18        2     1        1
# 13318  1900-06-18        4     1        1
# 13319  1900-07-18        1     1        1
#
# [13246 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13246 entries, 0 to 13319
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13246 non-null  int64
#  1   location    13246 non-null  object
#  2   total_sqft  13246 non-null  object
#  3   bath        13246 non-null  float64
#  4   price       13246 non-null  float64
#  5   month       13246 non-null  int32
#  6   date        13246 non-null  object
#  7   Bedroom     13246 non-null  int64
#  8   Hall        13246 non-null  int64
#  9   Kitchen     13246 non-null  int64
# dtypes: float64(2), int32(1), int64(4), object(3)
# memory usage: 1.6+ MB

# %%
df
# Out:
#        area_type                  location total_sqft  bath   price  month  \
# 0              1  Electronic City Phase II       1056   2.0   39.07     12
# 1              2          Chikka Tirupathi       2600   5.0  120.00      7
# 2              3               Uttarahalli       1440   2.0   62.00      7
# 3              1        Lingadheeranahalli       1521   3.0   95.00      7
# 4              1                  Kothanur       1200   2.0   51.00      7
# ...          ...                       ...        ...   ...     ...    ...
# 13315          3                Whitefield       3453   4.0  231.00      7
# 13316          1             Richards Town       3600   5.0  400.00      7
# 13317          3     Raja Rajeshwari Nagar       1141   2.0   60.00      7
# 13318          1           Padmanabhanagar       4689   4.0  488.00      6
# 13319          1              Doddathoguru        550   1.0   17.00      7
#
#              date  Bedroom  Hall  Kitchen
# 0      1900-12-19        2     1        1
# 1      1900-07-18        4     0        0
# 2      1900-07-18        3     1        1
# 3      1900-07-18        3     1        1
# 4      1900-07-18        2     1        1
# ...           ...      ...   ...      ...
# 13315  1900-07-18        5     0        0
# 13316  1900-07-18        4     1        1
# 13317  1900-07-18        2     1        1
# 13318  1900-06-18        4     1        1
# 13319  1900-07-18        1     1        1
#
# [13246 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['location']=le.fit_transform(df['location'])

# %%
df.drop("date",axis=1,inplace=True)

# %%
df
# Out:
#        area_type  location total_sqft  bath   price  month  Bedroom  Hall  \
# 0              1       419       1056   2.0   39.07     12        2     1
# 1              2       317       2600   5.0  120.00      7        4     0
# 2              3      1178       1440   2.0   62.00      7        3     1
# 3              1       756       1521   3.0   95.00      7        3     1
# 4              1       715       1200   2.0   51.00      7        2     1
# ...          ...       ...        ...   ...     ...    ...      ...   ...
# 13315          3      1251       3453   4.0  231.00      7        5     0
# 13316          1      1003       3600   5.0  400.00      7        4     1
# 13317          3       971       1141   2.0   60.00      7        2     1
# 13318          1       906       4689   4.0  488.00      6        4     1
# 13319          1       396        550   1.0   17.00      7        1     1
#
#        Kitchen
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1
# ...        ...
# 13315        0
# 13316        1
# 13317        1
# 13318        1
# 13319        1
#
# [13246 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13246 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13246 non-null  int64
#  1   location    13246 non-null  int64
#  2   total_sqft  13246 non-null  object
#  3   bath        13246 non-null  float64
#  4   price       13246 non-null  float64
#  5   month       13246 non-null  int32
#  6   Bedroom     13246 non-null  int64
#  7   Hall        13246 non-null  int64
#  8   Kitchen     13246 non-null  int64
# dtypes: float64(2), int32(1), int64(5), object(1)
# memory usage: 1.5+ MB

# %%
df['total_sqft']=pd.to_numeric(df['total_sqft'],errors="coerce")

# %%
df.isnull().sum()
# Out:
# area_type       0
# location        0
# total_sqft    190
# bath            0
# price           0
# month           0
# Bedroom         0
# Hall            0
# Kitchen         0
# dtype: int64

# %%
df['total_sqft']=pd.to_numeric(df['total_sqft'],errors='coerce')

# %%
df['bath'].fillna(df['bath'].mean(),inplace=True)

df['price'].fillna(df['price'].median(),inplace=True)

df['Bedroom'].fillna(df['Bedroom'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-1023361472.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bath'].fillna(df['bath'].mean(),inplace=True)
# /tmp/ipython-input-1023361472.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(df['price'].median(),inplace=True)
# /tmp/ipython-input-1023361472.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Bedroom'].fillna(df['Bedroom'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# area_type     0
# location      0
# total_sqft    0
# bath          0
# price         0
# month         0
# Bedroom       0
# Hall          0
# Kitchen       0
# dtype: int64

# %%
cm=df.corr()
sns.heatmap(cm,annot=True,fmt="0.1f",cmap="coolwarm")
plt.title("correlation mattrix")
plt.show()

# %%
survived_corr=df.corr()["price"]
survived_corr=survived_corr.drop('price')
sns.heatmap(survived_corr.to_frame(),annot=True,fmt='.2f',cmap='coolwarm',
            cbar=True,annot_kws={'size':10})
plt.title('Correlation between price and Other Features')
plt.show()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def remove_outliers_iqr(df,exclude_column):
    for col in df.columns:
        if col==exclude_column:
            continue
        Q1=df[col].quantile(0.25)
        Q3=df[col].quantile(0.75)
        IQR=Q3-Q1
        lower_bound=Q1-1.5*IQR
        upper_bound=Q3+1.5*IQR

        df=df[(df[col]>=lower_bound) & (df[col]<=upper_bound)]
    return df

df_cleaned=remove_outliers_iqr(df,exclude_column='price')
df=df_cleaned

# %%
df
# Out:
#        area_type  location  total_sqft  bath   price  month  Bedroom  Hall  \
# 3              1       756      1521.0   3.0   95.00      7        3     1
# 4              1       715      1200.0   2.0   51.00      7        2     1
# 5              1      1251      1170.0   2.0   38.00      7        2     1
# 8              1       798      1310.0   3.0   63.25      7        3     1
# 12             1        72      1000.0   2.0   38.00      7        2     1
# ...          ...       ...         ...   ...     ...    ...      ...   ...
# 13310          1       963      1050.0   2.0   52.71      7        2     1
# 13312          1       236      1262.0   2.0   47.00      7        2     1
# 13313          1      1178      1345.0   2.0   57.00      7        3     1
# 13314          1       474      1715.0   3.0  112.00      7        3     1
# 13319          1       396       550.0   1.0   17.00      7        1     1
#
#        Kitchen
# 3            1
# 4            1
# 5            1
# 8            1
# 12           1
# ...        ...
# 13310        1
# 13312        1
# 13313        1
# 13314        1
# 13319        1
#
# [6076 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6076 entries, 3 to 13319
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   6076 non-null   int64
#  1   location    6076 non-null   int64
#  2   total_sqft  6076 non-null   float64
#  3   bath        6076 non-null   float64
#  4   price       6076 non-null   float64
#  5   month       6076 non-null   int32
#  6   Bedroom     6076 non-null   int64
#  7   Hall        6076 non-null   int64
#  8   Kitchen     6076 non-null   int64
# dtypes: float64(3), int32(1), int64(5)
# memory usage: 451.0 KB

# %%
df.shape
# Out:
# (6076, 9)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
features=["area_type","location","total_sqft","bath","month","Bedroom","Hall","Kitchen"]
scaler=MinMaxScaler()
scaled_data=scaler.fit_transform(df[features])
scaled_df=pd.DataFrame(scaled_data,columns=features)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import pandas as pd
x=df[["area_type","location","total_sqft","bath","month","Hall","Kitchen"]]
y=df["price"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state=42)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
score = model.score(x_test, y_test)
print(f'Baseline model R^2 score: {score:.2f}')
# Out:
# Baseline model R^2 score: 0.55
