# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaydevverse/data-science-eda-ml-projects/blob/main/CustomerTravelEdaV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Customertravel.csv")

# %%
df
# Out:
#      Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0     34            No     Middle Income              6
# 1     34           Yes        Low Income              5
# 2     37            No     Middle Income              3
# 3     30            No     Middle Income              2
# 4     30            No        Low Income              1
# ..   ...           ...               ...            ...
# 949   31           Yes        Low Income              1
# 950   30            No     Middle Income              5
# 951   37            No     Middle Income              4
# 952   30            No        Low Income              1
# 953   31           Yes       High Income              1
#
#     AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                           No              Yes       0
# 1                          Yes               No       1
# 2                          Yes               No       0
# 3                           No               No       0
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# FrequentFlyer                 0
# AnnualIncomeClass             0
# ServicesOpted                 0
# AccountSyncedToSocialMedia    0
# BookedHotelOrNot              0
# Target                        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    object
#  2   AnnualIncomeClass           954 non-null    object
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    object
#  5   BookedHotelOrNot            954 non-null    object
#  6   Target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(507)

# %%
sns.countplot(data=df, x='Target')
plt.title("Target Distribution")
plt.show()

# %%
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.countplot(data=df, x='FrequentFlyer', hue='Target')
plt.title("Frequent Flyer vs Target")
plt.show()

# %%
sns.countplot(data=df, x='AnnualIncomeClass', hue='Target')
plt.title("Income Class vs Target")
plt.show()

# %%
sns.countplot(data=df, x='BookedHotelOrNot', hue='Target')
plt.title("Hotel Booking vs Target")
plt.show()

# %%
df
# Out:
#      Age FrequentFlyer AnnualIncomeClass  ServicesOpted  \
# 0     34            No     Middle Income              6
# 1     34           Yes        Low Income              5
# 2     37            No     Middle Income              3
# 3     30            No     Middle Income              2
# 4     30            No        Low Income              1
# ..   ...           ...               ...            ...
# 949   31           Yes        Low Income              1
# 950   30            No     Middle Income              5
# 951   37            No     Middle Income              4
# 952   30            No        Low Income              1
# 953   31           Yes       High Income              1
#
#     AccountSyncedToSocialMedia BookedHotelOrNot  Target
# 0                           No              Yes       0
# 1                          Yes               No       1
# 2                          Yes               No       0
# 3                           No               No       0
# ...

# %%
df['AnnualIncomeClass'].unique()
# Out:
# array(['Middle Income', 'Low Income', 'High Income'], dtype=object)

# %%
df['AccountSyncedToSocialMedia'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df["BookedHotelOrNot"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    object
#  2   AnnualIncomeClass           954 non-null    object
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    object
#  5   BookedHotelOrNot            954 non-null    object
#  6   Target                      954 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 52.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["FrequentFlyer"] = le.fit_transform(df["FrequentFlyer"])

# %%
df["FrequentFlyer"].unique()
# Out:
# array([0, 2, 1])

# %%
df["AnnualIncomeClass"].replace(["Low Income", "Middle Income", "High Income"],[0, 1, 2],inplace=True)
# Out:
# /tmp/ipython-input-3707685754.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["AnnualIncomeClass"].replace(["Low Income", "Middle Income", "High Income"],[0, 1, 2],inplace=True)
# /tmp/ipython-input-3707685754.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df["AccountSyncedToSocialMedia"].replace(["No", "Yes"], [0, 1], inplace=True)
# Out:
# /tmp/ipython-input-2628798069.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["AccountSyncedToSocialMedia"].replace(["No", "Yes"], [0, 1], inplace=True)
# /tmp/ipython-input-2628798069.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df["BookedHotelOrNot"].replace(["No", "Yes"], [0, 1], inplace=True)
# Out:
# /tmp/ipython-input-1234961575.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["BookedHotelOrNot"].replace(["No", "Yes"], [0, 1], inplace=True)
# /tmp/ipython-input-1234961575.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    int64
#  2   AnnualIncomeClass           954 non-null    int64
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    int64
#  5   BookedHotelOrNot            954 non-null    int64
#  6   Target                      954 non-null    int64
# dtypes: int64(7)
# memory usage: 52.3 KB

# %%
df.head()
# Out:
#    Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0   34              0                  1              6
# 1   34              2                  0              5
# 2   37              0                  1              3
# 3   30              0                  1              2
# 4   30              0                  0              1
#
#    AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                           0                 1       0
# 1                           1                 0       1
# 2                           1                 0       0
# 3                           0                 0       0
# 4                           0                 0       0

# %%
df
# Out:
#      Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0     34              0                  1              6
# 1     34              2                  0              5
# 2     37              0                  1              3
# 3     30              0                  1              2
# 4     30              0                  0              1
# ..   ...            ...                ...            ...
# 949   31              2                  0              1
# 950   30              0                  1              5
# 951   37              0                  1              4
# 952   30              0                  0              1
# 953   31              2                  2              1
#
#      AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                             0                 1       0
# 1                             1                 0       1
# 2                             1                 0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    int64
#  2   AnnualIncomeClass           954 non-null    int64
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    int64
#  5   BookedHotelOrNot            954 non-null    int64
#  6   Target                      954 non-null    int64
# dtypes: int64(7)
# memory usage: 52.3 KB

# %%
cm=df.corr()
sns.heatmap(cm,annot=True,fmt="0.1f",cmap="coolwarm")
plt.title("correlationmattrix")
plt.show()

# %%
survived_corr=df.corr()["Target"]
survived_corr=survived_corr.drop('Target')
sns.heatmap(survived_corr.to_frame(), annot=True, fmt='.2f', cmap='coolwarm',
            cbar=True, annot_kws={'size': 10})
plt.title('Correlation')
plt.show()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def remove_outliers_iqr(df,exclude_column):
  for col in df.columns:
    if col==exclude_column:
      continue
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR

    df=df[(df[col]>=lower_bound) & (df[col]<=upper_bound)]
  return df

df_cleaned=remove_outliers_iqr(df,exclude_column='Target')
df=df_cleaned

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         954 non-null    int64
#  1   FrequentFlyer               954 non-null    int64
#  2   AnnualIncomeClass           954 non-null    int64
#  3   ServicesOpted               954 non-null    int64
#  4   AccountSyncedToSocialMedia  954 non-null    int64
#  5   BookedHotelOrNot            954 non-null    int64
#  6   Target                      954 non-null    int64
# dtypes: int64(7)
# memory usage: 52.3 KB

# %%
df.shape
# Out:
# (954, 7)

# %%
df
# Out:
#      Age  FrequentFlyer  AnnualIncomeClass  ServicesOpted  \
# 0     34              0                  1              6
# 1     34              2                  0              5
# 2     37              0                  1              3
# 3     30              0                  1              2
# 4     30              0                  0              1
# ..   ...            ...                ...            ...
# 949   31              2                  0              1
# 950   30              0                  1              5
# 951   37              0                  1              4
# 952   30              0                  0              1
# 953   31              2                  2              1
#
#      AccountSyncedToSocialMedia  BookedHotelOrNot  Target
# 0                             0                 1       0
# 1                             1                 0       1
# 2                             1                 0       0
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

features=["Age", "ServicesOpted"]

scaler=MinMaxScaler()

scaled_data=scaler.fit_transform(df[features])

scaled_df=pd.DataFrame(scaled_data, columns=features)

scaled_df["Target"]=df["Target"]

scaled_df.head()
# Out:
#         Age  ServicesOpted  Target
# 0  0.636364            1.0       0
# 1  0.636364            0.8       1
# 2  0.909091            0.4       0
# 3  0.272727            0.2       0
# 4  0.272727            0.0       0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

X = df.drop("Target", axis=1)
y = df["Target"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

model=LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)

y_pred=model.predict(X_test)

accuracy=accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.82
