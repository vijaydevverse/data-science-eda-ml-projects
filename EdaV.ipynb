# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaydevverse/data-science-eda-ml-projects/blob/main/EdaV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EDA -  Exploratory Data Analysis**

# %% [markdown]
# It is the first and most important step in any data analysis or machine learning project .
#
# - The goal of EDA is to:-
#
#  - Summarize the main characteristics
#
#  - Visualize patterns, trends, and anomalies
#
#  - Clean the data if needed
#
#  - Understand the structure, distribution, and relationships in the data

# %% [markdown]
# Typical Steps in EDA:
#
# 1. Load and Inspect the Data
# 2. Understand the Data Types and Summary
# 3. Data Cleaning
# 4. Visualization
# 5. Correlation Analysis
# 6. Detect Outliers
# 7. Data Scaling

# %% [markdown]
# ## 1. Load and Inspect the Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the Titanic Dataset

df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ### **load dataset using python according to their file types**
#
# | File Type | File Extension  | Pandas Function              |
# | --------- | --------------- | ---------------------------- |
# | CSV       | `.csv`          | `pd.read_csv()`              |
# | Excel     | `.xls`, `.xlsx` | `pd.read_excel()`            |
# | JSON      | `.json`         | `pd.read_json()`             |
# | Parquet   | `.parquet`      | `pd.read_parquet()`          |
# | HDF5      | `.h5`, `.hdf5`  | `pd.read_hdf()`              |
# | Pickle    | `.pkl`          | `pd.read_pickle()`           |
# | HTML      | `.html`         | `pd.read_html()`             |
# | Text      | `.txt`          | `pd.read_csv()` (with `sep`) |

# %% [markdown]
# ## **2 .Understand the Data Types and Summary**

# %% [markdown]
# ### **to get the informations like :-**
#   * no of columns
#   * columns
#   * no of values in each column
#   * not null or not
#   * data types of values in column <br>
# **info()** is used

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ## **3. Data cleaning**

# %% [markdown]
# ###<b>To fill / drop empty cells, the fillna(), dropna() function can be used.</b>
# Null values can be filled with a specific value such as the mean, median, or mode of the column.
# Alternatively, the replace() function can also be used to substitute specific values, including NaNs, with desired ones.If you want to remove rows (or columns) that contain missing values entirely, use the dropna() function.

# %% [markdown]
# #### **Syntax : mean(),median(),mode()**
#   1.   DataFrame['column'].mean()
#   2.   DataFrame['column'].median()
#   3.   DataFrame['column'].mode()

# %% [markdown]
# #### **Syntax:**
# *   fillna() <br>
# DataFrame.fillna()
# *   replace()<br>
# DataFrame.replace()
# *   dropna() <br>
# DataFrame.dropna(inplace=True)# Drops rows with any NaN <br>
# DataFrame.dropna(axis=1, inplace=True)  # Drops columns with any NaN

# %% [markdown]
# ### Drop same columns/rows or unwanted columns/rows

# %%
df.drop(['class',"embarked",'alive'],axis=1,inplace=True)

# %% [markdown]
# **Checking null values**

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alone            0
# dtype: int64

# %% [markdown]
#  drop high number missing values column deck(Null>=50% of data)

# %%
df.drop("deck",axis=1,inplace=True)

# %% [markdown]
# ### Fill values
# - If its categorical data and also if a data is descrete numerical data fill using mode( )
#
# -  If a data is numerical  and continues fill with mean( ) if the data is normaly distributed or if its skewed fill with median( )

# %%
#drop less null value row using dropna()
df.dropna(subset=["embark_town"],inplace=True)

# %%
#check age distribution
df["age"].hist()
# Out:
# <Axes: >

# %%
#Age is skewed so fill with its median value
df["age"].fillna(df["age"].median(),inplace=True)
# Out:
# /tmp/ipython-input-3068220221.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df["age"].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# who            0
# adult_male     0
# embark_town    0
# alone          0
# dtype: int64

# %% [markdown]
# we can use **unique()** to find **distinct** values in a column and **value_counts()** to see the **frequency of each unique value**.

# %%
print(df['embark_town'].unique())
# Out:
# ['Southampton' 'Cherbourg' 'Queenstown']

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %% [markdown]
# ###  cheking  if in this dataset exists duplicates or not

# %%
df.duplicated().sum()
# Out:
# np.int64(116)

# %%
df.shape #check shape before droping duplicates
# Out:
# (889, 11)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (773, 11)

# %% [markdown]
# ## **5. Visualization**

# %%
plt.hist(df["survived"])
plt.show()

# %%
sns.histplot(df['age'],kde=True)
plt.show()

# %%
sns.countplot(data=df,x='pclass',hue='survived')
plt.show()

# %%
sns.countplot(data=df,x='sex',hue='survived')
plt.show()

# %%
sns.boxplot(data=df,x='survived',y='age')
plt.show()

# %%
sns.histplot(df['fare'],kde=True)
plt.show()

# %%
sns.countplot(data=df,x='embark_town',hue='survived')
plt.show()

# %%
sns.countplot(data=df,x='alone',hue='survived')
plt.show()

# %% [markdown]
# ##**6. Correlation Analysis in EDA**
# Correlation analysis is used to quantify the strength and direction of relationships between numerical variables. It helps identify how changes in one variable are associated with changes in another.

# %% [markdown]
# ### **Before checking correlation we need to convert all object data to numerical**

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare    who  adult_male  \
# 0         0       3    male  22.0      1      0   7.2500    man        True
# 1         1       1  female  38.0      1      0  71.2833  woman       False
# 2         1       3  female  26.0      0      0   7.9250  woman       False
# 3         1       1  female  35.0      1      0  53.1000  woman       False
# 4         0       3    male  35.0      0      0   8.0500    man        True
#
#    embark_town  alone
# 0  Southampton  False
# 1    Cherbourg  False
# 2  Southampton   True
# 3  Southampton  False
# 4  Southampton   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 773 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     773 non-null    int64
#  1   pclass       773 non-null    int64
#  2   sex          773 non-null    object
#  3   age          773 non-null    float64
#  4   sibsp        773 non-null    int64
#  5   parch        773 non-null    int64
#  6   fare         773 non-null    float64
#  7   who          773 non-null    object
#  8   adult_male   773 non-null    bool
#  9   embark_town  773 non-null    object
#  10  alone        773 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(3)
# memory usage: 61.9+ KB

# %%
#Converting all the nominal datas to numerical values using labelencoder class
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

#df['sex']=le.fit_transfrom(df['sex'])
df['who']=le.fit_transform(df['who'])
df['adult_male']=le.fit_transform(df['adult_male'])
df['alone']=le.fit_transform(df['alone'])
df['embark_town']=le.fit_transform(df['embark_town'])

# %%
df["sex"].isnull().sum()
# Out:
# np.int64(0)

# %%
dummies=pd.get_dummies(df["sex"]).astype(int)
dummies
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 885       1     0
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [773 rows x 2 columns]

# %%
df=pd.concat([df,dummies],axis="columns")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  who  adult_male  \
# 0           0       3    male  22.0      1      0   7.2500    1           1
# 1           1       1  female  38.0      1      0  71.2833    2           0
# 2           1       3  female  26.0      0      0   7.9250    2           0
# 3           1       1  female  35.0      1      0  53.1000    2           0
# 4           0       3    male  35.0      0      0   8.0500    1           1
# ..        ...     ...     ...   ...    ...    ...      ...  ...         ...
# 885         0       3  female  39.0      0      5  29.1250    2           0
# 887         1       1  female  19.0      0      0  30.0000    2           0
# 888         0       3  female  28.0      1      2  23.4500    2           0
# 889         1       1    male  26.0      0      0  30.0000    1           1
# 890         0       3    male  32.0      0      0   7.7500    1           1
#
#      embark_town  alone  female  male
# 0              2      0       0     1
# 1              0      0       1     0
# 2              2      1       1     0
# 3              2      0       1     0
# 4              2      1       0     1
# ..           ...    ...     ...   ...
# 885            1      0       1     0
# 887            2      1       1     0
# 888            2      0       1     0
# 889            0      1       0     1
# 890            1      1       0     1
#
# [773 rows x 13 columns]

# %%
#drop the original variable
df.drop(["sex"],axis="columns",inplace=True)
df
# Out:
#      survived  pclass   age  sibsp  parch     fare  who  adult_male  \
# 0           0       3  22.0      1      0   7.2500    1           1
# 1           1       1  38.0      1      0  71.2833    2           0
# 2           1       3  26.0      0      0   7.9250    2           0
# 3           1       1  35.0      1      0  53.1000    2           0
# 4           0       3  35.0      0      0   8.0500    1           1
# ..        ...     ...   ...    ...    ...      ...  ...         ...
# 885         0       3  39.0      0      5  29.1250    2           0
# 887         1       1  19.0      0      0  30.0000    2           0
# 888         0       3  28.0      1      2  23.4500    2           0
# 889         1       1  26.0      0      0  30.0000    1           1
# 890         0       3  32.0      0      0   7.7500    1           1
#
#      embark_town  alone  female  male
# 0              2      0       0     1
# 1              0      0       1     0
# 2              2      1       1     0
# 3              2      0       1     0
# 4              2      1       0     1
# ..           ...    ...     ...   ...
# 885            1      0       1     0
# 887            2      1       1     0
# 888            2      0       1     0
# 889            0      1       0     1
# 890            1      1       0     1
#
# [773 rows x 12 columns]

# %%
#Replace if a data is  ordinal data
#df["gender"].replace(["male","female"],[0,1],inplace=True)

# %% [markdown]
# ### After converting check correlation

# %%
#Correlation Matrix
corr_matrix=df.corr()

#Heatmap of correlation matrix
sns.heatmap(corr_matrix,annot=True,fmt='0.01f',cmap='coolwarm') #0.01f should be given for float values, d for integers
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### check : -Collinearity  ,multicollinearity

# %% [markdown]
# - Male and adult_male and female have multicollinearity so Take only one column  before droping check correlation to Target and drop less correlated

# %%
df.drop(["male","female"],axis=1,inplace=True)

# %%
#Calculate the correlation between 'survived' and all other columns
survived_corr=df.corr()['survived']

#Remove the correlation of 'survived'with itself (which is always 1)
survived_corr=survived_corr.drop('survived')

#Create a heatmap to visualize the correlations
sns.heatmap(survived_corr.to_frame(),annot=True,fmt='.2f',cmap='coolwarm',
            cbar=True,annot_kws={'size':10}) # to_frame() converts Series to DataFrame for heatmap
plt.title('Correlation between survived and other features')
plt.show()

# %% [markdown]
# ###  **Now remove less correlated**

# %%
df.drop(["age","sibsp","parch"],axis=1,inplace=True)

# %% [markdown]
# ## **7.Outlier cheking and removing**

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
#Function to remove outliers using the IQR method except for one column
def remove_outliers_iqr(df,exclude_column):
  for col in df.columns:
    #Skip the specified column
    if col==exclude_column:
      continue
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR
    #Filter the DataFrame to remove rows with outliers in each column
    df=df[(df[col]>=lower_bound)&(df[col]<=upper_bound)]
  return df
#Specify the column to exclude
df_cleaned=remove_outliers_iqr(df,exclude_column='survived')
df=df_cleaned

# %%
df.shape
# Out:
# (511, 7)

# %% [markdown]
# ## **8. Data Scaling**

# %% [markdown]
# - If in a data set two features have diffrent scale of data do scaling
#  - imagine if we have two features age and price so both are differnt scale so do scaling for better performance

# %% [markdown]
#  - minmax scaling - 0-1 range
#  - standard scaling - mean: 0 , standard deviation: 1  range

# %%
df
# Out:
#      survived  pclass     fare  who  adult_male  embark_town  alone
# 0           0       3   7.2500    1           1            2      0
# 2           1       3   7.9250    2           0            2      1
# 3           1       1  53.1000    2           0            2      0
# 4           0       3   8.0500    1           1            2      1
# 6           0       1  51.8625    1           1            2      1
# ..        ...     ...      ...  ...         ...          ...    ...
# 881         0       3   7.8958    1           1            2      1
# 882         0       3  10.5167    2           0            2      1
# 883         0       2  10.5000    1           1            2      1
# 887         1       1  30.0000    2           0            2      1
# 888         0       3  23.4500    2           0            2      0
#
# [511 rows x 7 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

#Select the features that you want to scale
features=['pclass','fare','embark_town',"who","adult_male","alone"]

#Create a MinMaxScaler Object
scaler=MinMaxScaler()

#Fit the scaler to your data and transform it
scaled_data=scaler.fit_transform(df[features])

#Create a DataFrame from scaled_data with the correct column names
scaled_df=pd.DataFrame(scaled_data,columns=features)

# %% [markdown]
# # After **EDA** we can predict

# %% [markdown]
# ### Use  LogisticRegression model if our dataset is classification  or if our dataset is regression use LinearRegression

# %%
# use logisticRegression because our dataset is classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd # Import pandas

X = df[['pclass', 'fare', 'embark_town',"pclass","who","adult_male","alone"]]  # Features
y = df['survived']  # Target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42) # You can adjust the test_size and random_state

# Train a baseline logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict and evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Baseline model accuracy: {accuracy:.2f}')
# Out:
# Baseline model accuracy: 0.77
